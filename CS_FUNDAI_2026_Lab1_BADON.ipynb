# %% [markdown]
# <a href="https://colab.research.google.com/github/lilad25/FUNDAI-Lab1-BADON/blob/main/CS_FUNDAI_2026_Lab1_BADON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Environment Onboarding
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Adrian N. Badon
# **Course:** BSIT - 4th Year
# **Section:** BSIT-4F
# **Date:** August 18, 2026
# **GitHub URL:** https://github.com/lilad25/FUNDAI-Lab1-BADON
#
# ## Description
#
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version)

print("Current date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Current date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

folder_path = "/content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: /content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1

# %% [markdown]
# ## Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# - If the room is dirty, the agent cleans.
# - If the room is clean, the agent rests.
# - If the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
    """
    A simple reflex agent that decides an action based on the room condition.
    """
    room_condition = room_condition.strip().lower()

    if room_condition == "dirty":
        return "CLEAN"
    elif room_condition == "clean":
        return "REST"
    else:
        return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
    action = simple_reflex_agent(percept)
    print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unknown  -> Action: INSPECT

# %% [markdown]
# ## Performance Measure
#
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
    action = simple_reflex_agent(percept)

    if percept == "dirty" and action == "CLEAN":
        score += 1
    elif percept == "clean" and action == "REST":
        score += 1
    elif percept == "unknown" and action == "INSPECT":
        score += 1

print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# An intelligent agent is a system that perceives its environment through sensors and acts upon that environment through actuators.
#
# ### 2. What is the environment in Lab 1’s simple agent example?
# The environment is the room whose condition can be dirty, clean, or unknown.
#
# ### 3. What serves as the percept?
# The percept is the room condition received by the agent, such as "dirty", "clean", or "unknown".
#
# ### 4. What serves as the action?
# The action is the response produced by the agent, such as CLEAN, REST, or INSPECT.
#
# ### 5. Why is a performance measure important?
# A performance measure is important because it helps evaluate whether the agent is choosing the correct action for each percept.
#
# ### 6. Why must AI outputs be saved to GitHub or Google Drive?
# AI outputs should be saved to GitHub or Google Drive because Colab runtimes are temporary and files stored only in the runtime can be lost after disconnection.
#
# ### 7. Why is Markdown documentation important in a Colab notebook?
# Markdown documentation explains the purpose of the activity, organizes the notebook, and makes the code and results easier to understand.
#
# ### 8. What problems can happen if a notebook is saved only inside the Colab runtime?
# The notebook or files may disappear when the runtime disconnects or resets.
#
# ### 9. Why is version control useful in AI development?
# Version control is useful because it tracks changes, keeps previous versions, and helps manage and organize development work.
#
# ### 10. Why does the course require two attempts for laboratory activities?
# The two-attempt policy allows students to first show progress and then submit a complete and improved final version.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# One challenge I encountered was becoming familiar with the Google Colab environment and understanding how code cells, Markdown cells, Google Drive, and GitHub work together. I also needed to make sure that the simple reflex agent produced the correct output for each room condition.
#
# ### What I Learned
# I learned how to create and run a Google Colab notebook, use Markdown for documentation, mount Google Drive, and implement a simple intelligent agent in Python. I also learned how a simple reflex agent uses condition-action rules to decide what action to perform based on the current percept.

# %% [markdown]
# ## Conclusion
#
# In this laboratory activity, I successfully learned how to use Google Colab and GitHub as tools for Artificial Intelligence laboratory work. I was able to create and run Python code, mount Google Drive, implement and test a simple reflex agent, and evaluate its performance. The activity also helped me understand the importance of proper documentation, cloud storage, and version control when developing AI projects.
